# %%
# Cell 1: Setup and Data
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Aggregated risk data
risk_data = [
    {"Risk_ID": "ARCH-SECURITY-01", "Severity": "High", "Likelihood": 4, "Impact": 4, "Risk_Type": "SECURITY", "SDLC_Phase": "Architecture"},
    {"Risk_ID": "ARCH-PERFORMANCE-01", "Severity": "Medium", "Likelihood": 3, "Impact": 3, "Risk_Type": "PERFORMANCE", "SDLC_Phase": "Architecture"},
    {"Risk_ID": "ARCH-QUALITY-01", "Severity": "Medium", "Likelihood": 3, "Impact": 3, "Risk_Type": "QUALITY", "SDLC_Phase": "Architecture"},
    {"Risk_ID": "ARCH-DEPLOYMENT-01", "Severity": "Medium", "Likelihood": 3, "Impact": 3, "Risk_Type": "DEPLOYMENT", "SDLC_Phase": "Architecture"},
    {"Risk_ID": "CONFIG-SECURITY-01", "Severity": "Critical", "Likelihood": 5, "Impact": 5, "Risk_Type": "SECURITY", "SDLC_Phase": "Coding"},
    {"Risk_ID": "CONFIG-SECURITY-02", "Severity": "High", "Likelihood": 4, "Impact": 4, "Risk_Type": "SECURITY", "SDLC_Phase": "Coding"},
    {"Risk_ID": "CODE-SECURITY-01", "Severity": "Medium", "Likelihood": 3, "Impact": 3, "Risk_Type": "SECURITY", "SDLC_Phase": "Coding"},
    {"Risk_ID": "CODE-QUALITY-01", "Severity": "Medium", "Likelihood": 3, "Impact": 3, "Risk_Type": "QUALITY", "SDLC_Phase": "Coding"},
    {"Risk_ID": "CODE-PERFORMANCE-01", "Severity": "Medium", "Likelihood": 3, "Impact": 3, "Risk_Type": "PERFORMANCE", "SDLC_Phase": "Coding"},
    {"Risk_ID": "UI-SECURITY-01", "Severity": "Medium", "Likelihood": 3, "Impact": 3, "Risk_Type": "SECURITY", "SDLC_Phase": "Coding"},
    {"Risk_ID": "DB-MAINTAINABILITY-01", "Severity": "Medium", "Likelihood": 3, "Impact": 3, "Risk_Type": "MAINTAINABILITY", "SDLC_Phase": "Coding"},
    {"Risk_ID": "LLM-SECURITY-01", "Severity": "Medium", "Likelihood": 3, "Impact": 3, "Risk_Type": "SECURITY", "SDLC_Phase": "Coding"},
    {"Risk_ID": "PLANNING-RESOURCING-01", "Severity": "High", "Likelihood": 4, "Impact": 4, "Risk_Type": "PLANNING", "SDLC_Phase": "Planning"},
    {"Risk_ID": "PLANNING-SCHEDULING-01", "Severity": "Medium", "Likelihood": 3, "Impact": 3, "Risk_Type": "PLANNING", "SDLC_Phase": "Planning"},
    {"Risk_ID": "PLANNING-DEPENDENCY-01", "Severity": "Medium", "Likelihood": 3, "Impact": 3, "Risk_Type": "PLANNING", "SDLC_Phase": "Planning"}
]

# Create DataFrame
df = pd.DataFrame(risk_data)

# Cell 2: Pie Chart - Risk Distribution by Severity
plt.figure(figsize=(8, 6))
severity_counts = df['Severity'].value_counts()
plt.pie(severity_counts, labels=severity_counts.index, autopct='%1.1f%%', colors=sns.color_palette('pastel'), startangle=140)
plt.title('Risk Distribution by Severity - Grok')
plt.show()

# Cell 3: Bar Chart - Risks by SDLC Phase
plt.figure(figsize=(10, 6))
phase_counts = df['SDLC_Phase'].value_counts()
sns.barplot(x=phase_counts.index, y=phase_counts.values, palette='muted')
plt.title('Risks by SDLC Phase - Grok')
plt.xlabel('SDLC Phase')
plt.ylabel('Number of Risks')
plt.show()

# Cell 4: Heatmap - Risk Likelihood vs Impact
plt.figure(figsize=(8, 6))
heatmap_data = pd.crosstab(df['Likelihood'], df['Impact'])
sns.heatmap(heatmap_data, annot=True, cmap='YlOrRd', fmt='d')
plt.title('Risk Likelihood vs Impact - Grok')
plt.xlabel('Impact')
plt.ylabel('Likelihood')
plt.show()

# Cell 5: Stacked Bar Chart - Risk Type Distribution per SDLC Phase
plt.figure(figsize=(12, 6))
pivot_table = df.pivot_table(index='SDLC_Phase', columns='Risk_Type', aggfunc='size', fill_value=0)
pivot_table.plot(kind='bar', stacked=True, colormap='Set2')
plt.title('Risk Type Distribution per SDLC Phase - Grok')
plt.xlabel('SDLC Phase')
plt.ylabel('Number of Risks')
plt.legend(title='Risk Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\zsj36405\AppData\Local\Temp\ipykernel_1180\2961948734.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=phase_counts.index, y=phase_counts.values, palette='muted')
